# %%
import os
import glob
import pandas as pd

# %%
basepath = "/home/abetatos/Escritorio/TFM_models/"
FEATURES = ["DEM", "SCE", "Aspect", "Slope", "TPI", "TPIWGW", "DEMSNOW", "FFSNOW"]

# %%
models = ["leave_one_out_sgd_adam", "leave_one_out_sgd"]

all_df = pd.DataFrame()
for model in models:
    files = glob.glob(basepath + model + "/*.pt")
    files_df = pd.DataFrame(files, columns=['filepath'])
    files_df['modeltype'] = model
    files_df['model'] = files_df['filepath'].apply(lambda x: os.path.basename(x).split("_")[0])
    files_df['variable'] = files_df['filepath'].apply(lambda x: x.split("_")[-1].replace(".pt", ""))
    files_df['report'] = files_df['model'].apply(lambda x: os.path.join(basepath, model, f"{x}_train_report.csv"))
    files_df['best'] = files_df['model'].apply(lambda x: os.path.join(basepath, model, f"{x}_best_report.csv"))
    # files_df.set_index('variable', inplace=True)

    all_df = pd.concat([all_df, files_df])

# %%
all_df
# Out:
#                                             filepath               modeltype
# 0  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam  \
# 1  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 2  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 3  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 4  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 5  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 6  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 7  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 8  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 9  /home/abetatos/Escritorio/TFM_models/leave_one...  leave_one_out_sgd_adam
# 0  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 1  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 2  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 3  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 4  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 5  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 6  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 7  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 8  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
# 9  /home/abetatos/Escritorio/TFM_models/leave_one...       leave_one_out_sgd
#
#         model variable                                             report
# 0  1686151512  0124567  /home/abetatos/Escritorio/TFM_models/leave_one...  \
# 1  1686162840  0123467  /home/abetatos/Escritorio/TFM_models/leave_one...
# 2  1686137565  1234567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 3  1686142186  0234567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 4  1686146844  0134567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 5  1686170073  0123457  /home/abetatos/Escritorio/TFM_models/leave_one...
# 6  1686174684  0123456  /home/abetatos/Escritorio/TFM_models/leave_one...
# 7  1686251883   012367  /home/abetatos/Escritorio/TFM_models/leave_one...
# 8  1686158229  0123567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 9  1686204539   123457  /home/abetatos/Escritorio/TFM_models/leave_one...
# 0  1686155932  0123567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 1  1686172400  0123456  /home/abetatos/Escritorio/TFM_models/leave_one...
# 2  1686144517  0134567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 3  1686167737  0123457  /home/abetatos/Escritorio/TFM_models/leave_one...
# 4  1686135210  1234567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 5  1686149181  0124567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 6  1686160559  0123467  /home/abetatos/Escritorio/TFM_models/leave_one...
# 7  1686206763   012367  /home/abetatos/Escritorio/TFM_models/leave_one...
# 8  1686139865  0234567  /home/abetatos/Escritorio/TFM_models/leave_one...
# 9  1686202317   123457  /home/abetatos/Escritorio/TFM_models/leave_one...
#
#                                                 best
# 0  /home/abetatos/Escritorio/TFM_models/leave_one...
# 1  /home/abetatos/Escritorio/TFM_models/leave_one...
# 2  /home/abetatos/Escritorio/TFM_models/leave_one...
# 3  /home/abetatos/Escritorio/TFM_models/leave_one...
# 4  /home/abetatos/Escritorio/TFM_models/leave_one...
# 5  /home/abetatos/Escritorio/TFM_models/leave_one...
# 6  /home/abetatos/Escritorio/TFM_models/leave_one...
# 7  /home/abetatos/Escritorio/TFM_models/leave_one...
# 8  /home/abetatos/Escritorio/TFM_models/leave_one...
# 9  /home/abetatos/Escritorio/TFM_models/leave_one...
# 0  /home/abetatos/Escritorio/TFM_models/leave_one...
# 1  /home/abetatos/Escritorio/TFM_models/leave_one...
# 2  /home/abetatos/Escritorio/TFM_models/leave_one...
# 3  /home/abetatos/Escritorio/TFM_models/leave_one...
# 4  /home/abetatos/Escritorio/TFM_models/leave_one...
# 5  /home/abetatos/Escritorio/TFM_models/leave_one...
# 6  /home/abetatos/Escritorio/TFM_models/leave_one...
# 7  /home/abetatos/Escritorio/TFM_models/leave_one...
# 8  /home/abetatos/Escritorio/TFM_models/leave_one...
# 9  /home/abetatos/Escritorio/TFM_models/leave_one...

# %%
best_models = []
for variable, var_df in all_df.groupby("variable"):
    for index, series in var_df.iterrows():
        train_report = pd.read_csv(series['best'])
        train_diff = train_report['Val loss 2'].values[0].round(3)
        
        # best_models.append([series['modeltype'], train_diff, FEATURES[int(variable)]])
        # best_models.append([series['modeltype'], train_diff, variable])
        best_models.append([series['modeltype'], train_diff, [FEATURES[v] for v in range(8) if str(v) not in variable]]) #Leave one out

best_models_df = pd.DataFrame(best_models, columns=["modelname", "score", "variable"])
best_by_model_df = pd.DataFrame()
for model, aux_df in best_models_df.groupby("modelname"):
    for index, series in aux_df.iterrows():
        best_by_model_df.at[model, str(series['variable'])] = series['score']

best_by_model_df.style.highlight_min(color = 'blue', 
                       axis = 0)
# Out:
# <style type="text/css">
# #T_12a9f_row1_col0, #T_12a9f_row1_col1, #T_12a9f_row1_col2, #T_12a9f_row1_col3, #T_12a9f_row1_col4, #T_12a9f_row1_col5, #T_12a9f_row1_col6, #T_12a9f_row1_col7, #T_12a9f_row1_col8, #T_12a9f_row1_col9 {
#   background-color: blue;
# }
# </style>
# <table id="T_12a9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12a9f_level0_col0" class="col_heading level0 col0" >['FFSNOW']</th>
#       <th id="T_12a9f_level0_col1" class="col_heading level0 col1" >['DEMSNOW']</th>
#       <th id="T_12a9f_level0_col2" class="col_heading level0 col2" >['TPIWGW']</th>
#       <th id="T_12a9f_level0_col3" class="col_heading level0 col3" >['TPI']</th>
#       <th id="T_12a9f_level0_col4" class="col_heading level0 col4" >['TPI', 'TPIWGW']</th>
#       <th id="T_12a9f_level0_col5" class="col_heading level0 col5" >['Slope']</th>
#       <th id="T_12a9f_level0_col6" class="col_heading level0 col6" >['Aspect']</th>
#       <th id="T_12a9f_level0_col7" class="col_heading level0 col7" >['SCE']</th>
#       <th id="T_12a9f_level0_col8" class="col_heading level0 col8" >['DEM']</th>
#       <th id="T_12a9f_level0_col9" class="col_heading level0 col9" >['DEM', 'DEMSNOW']</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12a9f_level0_row0" class="row_heading level0 row0" >leave_one_out_sgd</th>
#       <td id="T_12a9f_row0_col0" class="data row0 col0" >0.561000</td>
#       <td id="T_12a9f_row0_col1" class="data row0 col1" >0.557000</td>
#       <td id="T_12a9f_row0_col2" class="data row0 col2" >0.571000</td>
#       <td id="T_12a9f_row0_col3" class="data row0 col3" >0.589000</td>
#       <td id="T_12a9f_row0_col4" class="data row0 col4" >0.589000</td>
#       <td id="T_12a9f_row0_col5" class="data row0 col5" >0.568000</td>
#       <td id="T_12a9f_row0_col6" class="data row0 col6" >0.565000</td>
#       <td id="T_12a9f_row0_col7" class="data row0 col7" >0.578000</td>
#       <td id="T_12a9f_row0_col8" class="data row0 col8" >0.572000</td>
#       <td id="T_12a9f_row0_col9" class="data row0 col9" >0.567000</td>
#     </tr>
#     <tr>
#       <th id="T_12a9f_level0_row1" class="row_heading level0 row1" >leave_one_out_sgd_adam</th>
#       <td id="T_12a9f_row1_col0" class="data row1 col0" >0.536000</td>
#       <td id="T_12a9f_row1_col1" class="data row1 col1" >0.522000</td>
#       <td id="T_12a9f_row1_col2" class="data row1 col2" >0.546000</td>
#       <td id="T_12a9f_row1_col3" class="data row1 col3" >0.570000</td>
#       <td id="T_12a9f_row1_col4" class="data row1 col4" >0.561000</td>
#       <td id="T_12a9f_row1_col5" class="data row1 col5" >0.539000</td>
#       <td id="T_12a9f_row1_col6" class="data row1 col6" >0.558000</td>
#       <td id="T_12a9f_row1_col7" class="data row1 col7" >0.560000</td>
#       <td id="T_12a9f_row1_col8" class="data row1 col8" >0.548000</td>
#       <td id="T_12a9f_row1_col9" class="data row1 col9" >0.529000</td>
#     </tr>
#   </tbody>
# </table>
