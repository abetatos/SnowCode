# %%
import json
import os
from importlib import reload

import src.pre_trainer as t
# Out:
# /home/abetatos/Escritorio/TFM_src/torch/src/pre_trainer.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
FEATURES = ["DEM", "SCE", "Aspect", "Slope", "TPI", "TPIWGW", "DEMSNOW", "FFSNOW"]


os.environ['displayprob'] = "0"
os.environ['Features'] = json.dumps(FEATURES)

batch_size = 128
config = "256pixel_4ro"
dataset_path = f"/home/abetatos/Escritorio/TFM_Dataset/Dataset_20230523/{config}/"

# %%
# index_vars = [0, 1, 2, 3, 4, 5, 6, 7]

# trainer.init_trainer(ini_channels=8, out_channels=1, width=12, depth=7, lr=1e-3, eps=1e-4)
# # trainer.pretrain(batch_size = batch_size, n_epochs=4, index_vars=index_vars) 

# val1, val2, loss = trainer.train(batch_size = batch_size, n_epochs=12, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7, 8]
# trainer.clear_model()

# %%
# for index_vars in [[0,1,2,3,6,7]]:
for i in list(range(8)):
    index_vars = [j for j in range(8) if i!=j]

    trainer = t.Trainer("UpNet", "SGD", dataset_path)
    
    print("_"*100)
    print([trainer.FEATURES[in_var] for in_var in index_vars], "\n")
    
    trainer.init_trainer(ini_channels=7, out_channels=1, width=12, depth=7, lr=1e-3, eps=1e-4, momentum=0.9, weight_decay=1e-5, nesterov=True)
    # trainer.pretrain(batch_size = batch_size, n_epochs=10, index_vars=index_vars)
    val1, val2, loss, modelname = trainer.train(batch_size = 128, n_epochs=15, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7]
    trainer.load_checkpoint(modelname)
    trainer.update_optimizer("Adam")

    val1, val2, loss, modelname = trainer.train(batch_size = 128, n_epochs=15, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7]
    trainer.clear_model()
# Out:
# ____________________________________________________________________________________________________
# ['SCE', 'Aspect', 'Slope', 'TPI', 'TPIWGW', 'DEMSNOW', 'FFSNOW']
# ...
#   0%|          | 0/7 [00:00<?, ?it/s]
# ╔══════════════╦════════════╦═══════════════╦═══════════════╗
# ║  Epoch       ║  TrainVal  ║  Validation2  ║  Validation1  ║
# ╠══════════════╬════════════╬═══════════════╬═══════════════╣
# ║  1           ║  0.679     ║  0.679        ║  0.781        ║
# ╚══════════════╩════════════╩═══════════════╩═══════════════╝
# ...
#   0%|          | 0/7 [00:00<?, ?it/s]
# ╔══════════════╦════════════╦═══════════════╦═══════════════╗
# ║  Epoch       ║  TrainVal  ║  Validation2  ║  Validation1  ║
# ╠══════════════╬════════════╬═══════════════╬═══════════════╣
# ║  2           ║  0.621     ║  0.587        ║  0.738        ║
# ╚══════════════╩════════════╩═══════════════╩═══════════════╝
# ...
#   0%|          | 0/7 [00:00<?, ?it/s]
# ╔══════════════╦════════════╦═══════════════╦═══════════════╗
# ...

# %%
index_vars = [0, 1, 2, 3, 4, 5, 6, 7]

trainer = t.Trainer("UpNet", "SGD", dataset_path)
trainer.init_trainer(ini_channels=8, out_channels=1, width=12, depth=7, lr=1e-3, eps=1e-4, momentum=0.9, weight_decay=1e-5, nesterov=True)
trainer.pretrain(batch_size = batch_size, n_epochs=10, index_vars=index_vars)
val1, val2, loss, modelname = trainer.train(batch_size = 128, n_epochs=5, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7]

trainer.load_checkpoint(modelname)
trainer.update_optimizer("Adam")
val1, val2, loss, modelname = trainer.train(batch_size = 128, n_epochs=10, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7]
trainer.clear_model()
# Out:
# ...
#   5%|▌         | 1/19 [00:05<01:33,  5.21s/it]

# %%
# # ordervars = ('SCE', 'DEM', 'TPI', 'DEMSNOW', 'FFSNOW', 'Aspect', 'TPIWGW', 'Slope') # ada
# ordervars = ('DEM','Slope', 'SCE', 'TPI', 'Aspect', 'FFSNOW', 'DEMSNOW', 'TPIWGW') #ptimizer sgd ada

# index_vars = []
# for var in ordervars: 
#     i = FEATURES.index(var)
#     index_vars.append(i)
#     index_vars.sort()

#     print("_"*100)
#     print(index_vars, "\n")
    
#     trainer = t.Trainer("UpNet", "SGD", dataset_path)
#     trainer.init_trainer(ini_channels=len(index_vars), out_channels=1, width=12, depth=7, lr=1e-3, eps=1e-4)
#     # trainer.pretrain(batch_size = batch_size, n_epochs=3, index_vars=index_vars)
#     val1, val2, loss, modelname = trainer.train(batch_size = 128, n_epochs=15, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7]

#     trainer.load_checkpoint(modelname)
#     trainer.update_optimizer("Adam")

#     val1, val2, loss, modelname = trainer.train(batch_size = 128, n_epochs=15, index_vars=index_vars) # [0, 1, 2, 3, 4, 5, 6, 7]

#     trainer.clear_model()
